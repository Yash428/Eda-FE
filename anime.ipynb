# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\YASH PATEL\\Desktop\\data\\anime\\animes.csv')

# %%
df.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
# ...

# %%
df.describe()
# Out:
#                 uid      episodes       members    popularity        ranked  \
# count  19311.000000  18605.000000  1.931100e+04  19311.000000  16099.000000
# mean   19358.904096     11.460414  3.472609e+04   7720.830304   6866.524194
# std    14271.446515     47.950386  1.121772e+05   4676.786104   4390.018768
# min        1.000000      1.000000  2.500000e+01      1.000000      1.000000
# 25%     4833.500000      1.000000  3.880000e+02   3725.000000   2895.500000
# 50%    18327.000000      2.000000  2.389000e+03   7539.000000   6963.000000
# 75%    33896.500000     12.000000  1.450150e+04  11613.000000  10601.500000
# max    40960.000000   3057.000000  1.871043e+06  16338.000000  14675.000000
#
#               score
# count  18732.000000
# mean       6.436107
# std        1.007941
# min        1.250000
# 25%        5.770000
# 50%        6.410000
# 75%        7.150000
# max        9.230000

# %%
df.dtypes
# Out:
# uid             int64
# title          object
# synopsis       object
# genre          object
# aired          object
# episodes      float64
# members         int64
# popularity      int64
# ranked        float64
# score         float64
# img_url        object
# link           object
# dtype: object

# %%
df1 = df[['episodes','members','popularity','ranked','score']]

# %%
sns.pairplot(data=df1.corr())
# Out:
# C:\Users\YASH PATEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df1.corr()
# Out:
#             episodes   members  popularity    ranked     score
# episodes    1.000000  0.073963   -0.035215 -0.057196  0.073052
# members     0.073963  1.000000   -0.448320 -0.408786  0.426010
# popularity -0.035215 -0.448320    1.000000  0.854241 -0.694138
# ranked     -0.057196 -0.408786    0.854241  1.000000 -0.834105
# score       0.073052  0.426010   -0.694138 -0.834105  1.000000

# %%
sns.heatmap(data=df1.corr())
# Out:
# <Axes: >
